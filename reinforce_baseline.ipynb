# %%
from reinforce_baseline import *
from utils import *
# %load_ext autoreload
# %autoreload 2

# %%
metrics = {
    "returns": [],
    "t": []
}

for i in range(1):
    results = reinforce_baseline_cartpole()
    metrics["returns"].append(results[0])
    metrics["t"].append(results[1])
    
plot_return_per_episode(metrics)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 7
#       1 metrics = {
#       2     "returns": [],
#       3     "t": []
#       4 }
#       6 for i in range(1):
# ----> 7     results = reinforce_baseline_cartpole()
#       8     metrics["returns"].append(results[0])
#       9     metrics["t"].append(results[1])
#
# File ~/Projects/rl-working-name/reinforce_baseline.py:49, in reinforce_baseline_cartpole()
#      46 svalue_loss = F.mse_loss(svalue(state), G)
#      47 policy_loss = svalue_loss.item() * -action[1]
# ---> 49 policy_loss.backward()
#      50 svalue_loss.backward()
#      52 svalue_optimizer.step()
#
# File ~/Projects/rl-working-name/rl_venv/lib/python3.8/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
# ...

# %%
plot_t_per_episode(metrics)

# %%
plot_action_per_episode(metrics)

# %%
metrics = {
    "returns": [],
    "t": []
}

for i in range(3):
    results = reinforce_baseline_gridworld()
    metrics["returns"].append(results[0])
    metrics["t"].append(results[1])
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
plot_return_per_episode(metrics)

# %%
plot_t_per_episode(metrics)

# %%
plot_action_per_episode(metrics)
